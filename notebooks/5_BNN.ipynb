# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow import keras
from keras import layers

from keras.metrics import Accuracy
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error
# Out:
# 2025-01-30 16:35:42.093034: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-30 16:35:42.673691: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ### Load data if training is already done

# %%
data = np.load('../Results/lat.npz')
trainLat = data['xTrain']
testLat = data['xTest']

data = np.load('../Results/lon.npz')
trainLon = data['xTrain']
testLon = data['xTest']

data = np.load('../Results/trainScaled_pca.npz')
scaledXtrain_pca = data['xTrain']
yTrain = data['yTrain']

data = np.load('../Results/testScaled_pca.npz')
scaledXtest_pca = data['xTest']
yTest = data['yTest']

data = np.load('../Results/test.npz')
xTest = data['xTest']

# %% [markdown]
# ### Pre-processing for training

# %%
f = "../Results/ML_Data_1HR.pkl"
data = pd.read_pickle(f)
data.head(3)
# Out:
#         fahrenheit    zscore      ndvi     lstLat     lstLon stationID  \
# 46460    61.156944 -1.895117  0.333525  39.343576 -76.710610       LGC
# 118497   73.995790  1.305722  0.266438  39.307951 -76.592487       ARK
# 163026   85.743195  1.034689  0.012722  39.243907 -76.530551       ARK
#
#                       tz                 obsTimeUtc         obsTimeLocal  \
# 46460   America/New_York  2023-08-31 14:59:00+00:00  2023-08-31 10:59:00
# 118497  America/New_York  2023-08-31 14:59:00+00:00  2023-08-31 10:59:00
# 163026  America/New_York  2023-08-23 14:59:00+00:00  2023-08-23 10:59:00
#
#              epoch  ...  windchillLow  windchillAvg  heatindexHigh  \
# 46460   1693493940  ...          20.5          21.0           21.1
# 118497  1693493940  ...          22.0          22.6           22.7
# 163026  1692802740  ...          24.8          25.6           26.9
#
#         heatindexLow  heatindexAvg  pressureMax  pressureMin  pressureTrend  \
# 46460           20.5          20.8      1013.72      1012.80           0.52
# 118497          21.6          22.1      1008.81      1007.89           0.62
# 163026          24.5          25.4      1015.92      1015.31          -0.32
#
#         precipRate  precipTotal
# 46460          0.0          0.0
# 118497         0.0          0.0
# 163026         0.0          0.0
#
# [3 rows x 43 columns]

# %% [markdown]
# ### Drop time, quality control, and location based columns

# %%
data['qcStatus'].value_counts()
# Out:
# qcStatus
# 1    669309
# Name: count, dtype: int64

# %%
y = data['fahrenheit']

x = data.drop( columns=['fahrenheit','zscore','epoch','tz',
                        'stationID', 'obsTimeUtc', 'obsTimeLocal', 'qcStatus',
                        'bsecLat', 'bsecLon','precipRate','precipTotal'] )
x.shape
# Out:
# (669309, 31)

# %% [markdown]
# ### Convert temperature to Celcius to match BSEC data

# %%
y = (y - 32.) * (5/9)

# %%
x.columns
# Out:
# Index(['ndvi', 'lstLat', 'lstLon', 'bsecDistance', 'solarRadiationHigh',
#        'uvHigh', 'winddirAvg', 'humidityHigh', 'humidityLow', 'humidityAvg',
#        'tempHigh', 'tempLow', 'tempAvg', 'windspeedHigh', 'windspeedLow',
#        'windspeedAvg', 'windgustHigh', 'windgustLow', 'windgustAvg',
#        'dewptHigh', 'dewptLow', 'dewptAvg', 'windchillHigh', 'windchillLow',
#        'windchillAvg', 'heatindexHigh', 'heatindexLow', 'heatindexAvg',
#        'pressureMax', 'pressureMin', 'pressureTrend'],
#       dtype='object')

# %% [markdown]
# ### Train/Test Split

# %%
x.shape
# Out:
# (669309, 31)

# %%
np.max( x['bsecDistance'] )
# Out:
# 12.97432291059264

# %%
# stratify train/test split by distance to BSEC station

#  Create the bins
bins = np.arange(0, 14, 1)

# Save Y values in a new ndarray, broken down by the bins created above
binned = np.digitize( x['bsecDistance'], bins )

# %%
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, 
                                                random_state=42, stratify=binned)

# %%
xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
# Out:
# ((535447, 31), (535447,), (133862, 31), (133862,))

# %%
trainLat = xTrain['lstLat']
testLat = xTest['lstLat']

trainLon = xTrain['lstLon']
testLon = xTest['lstLon']

xTrain = xTrain.drop( columns=['lstLat','lstLon'] )
xTest = xTest.drop( columns=['lstLat','lstLon'] )

xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
# Out:
# ((535447, 29), (535447,), (133862, 29), (133862,))

# %%
scaler = StandardScaler()
scaler.fit(xTrain)
scaledXtrain = scaler.transform(xTrain)
scaledXtest = scaler.transform(xTest)

# %%
np.savez("../Results/lat", xTrain=trainLat, xTest=testLat)
np.savez("../Results/lon", xTrain=trainLon, xTest=testLon)

np.savez("../Results/train", xTrain=xTrain, yTrain=yTrain)
np.savez("../Results/test", xTest=xTest, yTest=yTest)
np.savez("../Results/trainScaled", xTrain=scaledXtrain, yTrain=yTrain)
np.savez("../Results/testScaled", xTest=scaledXtest, yTest=yTest)

# %% [markdown]
# ### Principal Component Analysis for feature reduction

# %%
import pickle
from sklearn.decomposition import PCA

variance_threshold = 0.95
pca = PCA(n_components=variance_threshold, svd_solver='full')
scaledXtrain_pca = pca.fit_transform(scaledXtrain)
scaledXtest_pca = pca.fit_transform(scaledXtest)

print( X_reduced.shape, scaledXtrain.shape )

with open('./scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)
    
with open('./pca.pkl', 'wb') as file:
    pickle.dump(pca, file)
# Out:
# (535447, 7) (535447, 29)

# %%
np.savez("../Results/trainScaled_pca", xTrain=scaledXtrain_pca, yTrain=yTrain)
np.savez("../Results/testScaled_pca", xTest=scaledXtest_pca, yTest=yTest)

# %% [markdown]
# ### Bayesian Neural Network

# %%
# Methods to calculate aleatoric and epistemic uncertainty based on 
# formulas from study by Valdenegro-Toro and Mori

# Aleatoric uncertainty is defined as the mean of variances
def getAleatoric( variances ):

    aleatoric = []
    n = len( variances[0] ) # total number predictions made
    nEnsemble = len( variances ) # number of ensemble members

    for i in range(n):
        var = []
        for j in range(nEnsemble):
            var.append(variances[j][i])
        aleatoric.append( np.mean(var) )

    return aleatoric

# Epistemic uncertainty is defined as the variance of means
def getEpistemic( means ):

    epistemic = []
    n = len( means[0] ) # total number predictions made
    nEnsemble = len( means ) # number of ensemble members

    for i in range(n):
        mns = []
        for j in range(nEnsemble):
            mns.append(means[j][i])
        m = np.mean( mns )
        mns = np.array(mns)
        diffs = mns**2 - m**2
        epistemic.append( np.mean(diffs) )

    return epistemic

# %%
# Custom Loss Function - Negative log Likelihood 
def nll(y_true, y_pred):
    return -y_pred.log_prob(y_true)

# %%
# Define the prior weight distribution as Normal of mean=0 and stddev=1
# The prior distribution is not trainable, as we fix its parameters
def prior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    prior_model = keras.Sequential(
        [
            tfp.layers.DistributionLambda(
                lambda t: tfp.distributions.MultivariateNormalDiag(
                    loc=tf.zeros(n), scale_diag=tf.ones(n)
                )
            )
        ]
    )
    return prior_model

# Define variational posterior weight distribution as multivariate Gaussian
# Note that the learnable parameters for this distribution are the means,
# variances, and covariances
def posterior(kernel_size, bias_size, dtype=None):
    n = kernel_size + bias_size
    posterior_model = keras.Sequential(
        [
            tfp.layers.VariableLayer(
                tfp.layers.MultivariateNormalTriL.params_size(n), dtype=dtype
            ),
            tfp.layers.MultivariateNormalTriL(n),
        ]
    )
    return posterior_model

# %%
from keras import backend as K 

# Keras keeps models hanging around in memory. If we retrain a model, Keras will
# start from the previously concluded weight values. This resets everything.
K.clear_session()

# %%
inputs = tf.keras.Input( scaledXtrain_pca.shape[1] )

# first hidden layer
hidden1 = tfp.layers.DenseVariational(units=14,
                                      make_prior_fn=prior,
                                      make_posterior_fn=posterior,
                                      kl_weight=1/len(scaledXtrain_pca),
                                      activation='sigmoid')(inputs)

# second hidden layer
hidden2 = tfp.layers.DenseVariational(units=7,
                                      make_prior_fn=prior,
                                      make_posterior_fn=posterior,
                                      kl_weight=1/len(scaledXtrain_pca),
                                      activation='sigmoid')(hidden1)

# Define output layer with 2 parameters (mean and variance)
distribution_params = Dense(units=2)(hidden2)
outputs = tfp.layers.IndependentNormal(1)(distribution_params)

bnn = keras.Model(inputs=inputs, outputs=outputs)

bnn.compile(loss=nll, optimizer=keras.optimizers.RMSprop(learning_rate=0.001))
# Out:
# 2025-01-30 16:36:39.967729: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5337 MB memory:  -> device: 0, name: NVIDIA GeForce GTX TITAN Black, pci bus id: 0000:65:00.0, compute capability: 3.5

# %%
bnn.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 7)]               0
#
#  dense_variational (DenseVar  (None, 14)               6440
#  iational)
#
#  dense_variational_1 (DenseV  (None, 7)                5670
#  ariational)
#
#  dense (Dense)               (None, 2)                 16
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 12,126
# Trainable params: 12,126
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = bnn.fit( scaledXtrain_pca, yTrain, epochs=200, verbose=1, 
                     validation_split=0.2, batch_size=256 )
# Out:
# Epoch 1/200
# 1674/1674 [==============================] - 15s 8ms/step - loss: 54.5948 - val_loss: 4.0261
# Epoch 2/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 3.3424 - val_loss: 2.7218
# Epoch 3/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.5468 - val_loss: 2.4276
# Epoch 4/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.3647 - val_loss: 2.3228
# Epoch 5/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.2829 - val_loss: 2.2604
# Epoch 6/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.2336 - val_loss: 2.2074
# Epoch 7/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.1861 - val_loss: 2.1708
# Epoch 8/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.1513 - val_loss: 2.1409
# Epoch 9/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.1278 - val_loss: 2.1269
# Epoch 10/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.1060 - val_loss: 2.1092
# Epoch 11/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0913 - val_loss: 2.0828
# Epoch 12/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0747 - val_loss: 2.0706
# Epoch 13/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0588 - val_loss: 2.0461
# Epoch 14/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0426 - val_loss: 2.0364
# Epoch 15/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0276 - val_loss: 2.0181
# Epoch 16/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0169 - val_loss: 2.0110
# Epoch 17/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 2.0039 - val_loss: 2.0005
# Epoch 18/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9943 - val_loss: 1.9913
# Epoch 19/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9842 - val_loss: 1.9819
# Epoch 20/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9755 - val_loss: 1.9716
# Epoch 21/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9672 - val_loss: 1.9594
# Epoch 22/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9606 - val_loss: 1.9561
# Epoch 23/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9524 - val_loss: 1.9501
# Epoch 24/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9471 - val_loss: 1.9442
# Epoch 25/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9435 - val_loss: 1.9319
# Epoch 26/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9378 - val_loss: 1.9349
# Epoch 27/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9334 - val_loss: 1.9290
# Epoch 28/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9300 - val_loss: 1.9255
# Epoch 29/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9257 - val_loss: 1.9212
# Epoch 30/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9229 - val_loss: 1.9229
# Epoch 31/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9197 - val_loss: 1.9174
# Epoch 32/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9157 - val_loss: 1.9228
# Epoch 33/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9135 - val_loss: 1.9126
# Epoch 34/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9100 - val_loss: 1.9115
# Epoch 35/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9082 - val_loss: 1.9063
# Epoch 36/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9053 - val_loss: 1.9036
# Epoch 37/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9031 - val_loss: 1.9008
# Epoch 38/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9022 - val_loss: 1.9066
# Epoch 39/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.9004 - val_loss: 1.9014
# Epoch 40/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8976 - val_loss: 1.8959
# Epoch 41/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8981 - val_loss: 1.8937
# Epoch 42/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8956 - val_loss: 1.8958
# Epoch 43/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8937 - val_loss: 1.8895
# Epoch 44/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8927 - val_loss: 1.8865
# Epoch 45/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8918 - val_loss: 1.8922
# Epoch 46/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8901 - val_loss: 1.8913
# Epoch 47/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8902 - val_loss: 1.8886
# Epoch 48/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8877 - val_loss: 1.8894
# Epoch 49/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8870 - val_loss: 1.8859
# Epoch 50/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8862 - val_loss: 1.8835
# Epoch 51/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8842 - val_loss: 1.8841
# Epoch 52/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8839 - val_loss: 1.8816
# Epoch 53/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8811 - val_loss: 1.8802
# Epoch 54/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8815 - val_loss: 1.8805
# Epoch 55/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8799 - val_loss: 1.8777
# Epoch 56/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8784 - val_loss: 1.8773
# Epoch 57/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8777 - val_loss: 1.8784
# Epoch 58/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8761 - val_loss: 1.8784
# Epoch 59/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8760 - val_loss: 1.8755
# Epoch 60/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8742 - val_loss: 1.8728
# Epoch 61/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8747 - val_loss: 1.8758
# Epoch 62/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8726 - val_loss: 1.8724
# Epoch 63/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8721 - val_loss: 1.8755
# Epoch 64/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8711 - val_loss: 1.8722
# Epoch 65/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8707 - val_loss: 1.8733
# Epoch 66/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8706 - val_loss: 1.8704
# Epoch 67/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8703 - val_loss: 1.8687
# Epoch 68/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8696 - val_loss: 1.8672
# Epoch 69/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8684 - val_loss: 1.8713
# Epoch 70/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8680 - val_loss: 1.8714
# Epoch 71/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8679 - val_loss: 1.8673
# Epoch 72/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8678 - val_loss: 1.8667
# Epoch 73/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8679 - val_loss: 1.8653
# Epoch 74/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8662 - val_loss: 1.8652
# Epoch 75/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8660 - val_loss: 1.8637
# Epoch 76/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8658 - val_loss: 1.8644
# Epoch 77/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8657 - val_loss: 1.8650
# Epoch 78/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8653 - val_loss: 1.8667
# Epoch 79/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8646 - val_loss: 1.8650
# Epoch 80/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8650 - val_loss: 1.8637
# Epoch 81/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8639 - val_loss: 1.8655
# Epoch 82/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8635 - val_loss: 1.8626
# Epoch 83/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8635 - val_loss: 1.8638
# Epoch 84/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8636 - val_loss: 1.8633
# Epoch 85/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8630 - val_loss: 1.8616
# Epoch 86/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8633 - val_loss: 1.8605
# Epoch 87/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8622 - val_loss: 1.8625
# Epoch 88/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8616 - val_loss: 1.8637
# Epoch 89/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8619 - val_loss: 1.8652
# Epoch 90/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8614 - val_loss: 1.8623
# Epoch 91/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8617 - val_loss: 1.8613
# Epoch 92/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8608 - val_loss: 1.8592
# Epoch 93/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8602 - val_loss: 1.8618
# Epoch 94/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8601 - val_loss: 1.8612
# Epoch 95/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8602 - val_loss: 1.8595
# Epoch 96/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8599 - val_loss: 1.8600
# Epoch 97/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8603 - val_loss: 1.8606
# Epoch 98/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8594 - val_loss: 1.8595
# Epoch 99/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8594 - val_loss: 1.8583
# Epoch 100/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8589 - val_loss: 1.8583
# Epoch 101/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8595 - val_loss: 1.8581
# Epoch 102/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8587 - val_loss: 1.8570
# Epoch 103/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8583 - val_loss: 1.8587
# Epoch 104/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8590 - val_loss: 1.8573
# Epoch 105/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8585 - val_loss: 1.8595
# Epoch 106/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8579 - val_loss: 1.8587
# Epoch 107/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8576 - val_loss: 1.8588
# Epoch 108/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8575 - val_loss: 1.8565
# Epoch 109/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8573 - val_loss: 1.8568
# Epoch 110/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8571 - val_loss: 1.8562
# Epoch 111/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8569 - val_loss: 1.8550
# Epoch 112/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8565 - val_loss: 1.8566
# Epoch 113/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8570 - val_loss: 1.8547
# Epoch 114/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8564 - val_loss: 1.8574
# Epoch 115/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8563 - val_loss: 1.8576
# Epoch 116/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8562 - val_loss: 1.8577
# Epoch 117/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8561 - val_loss: 1.8576
# Epoch 118/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8561 - val_loss: 1.8555
# Epoch 119/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8559 - val_loss: 1.8558
# Epoch 120/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8551 - val_loss: 1.8544
# Epoch 121/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8558 - val_loss: 1.8535
# Epoch 122/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8551 - val_loss: 1.8563
# Epoch 123/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8559 - val_loss: 1.8533
# Epoch 124/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8551 - val_loss: 1.8542
# Epoch 125/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8550 - val_loss: 1.8544
# Epoch 126/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8546 - val_loss: 1.8537
# Epoch 127/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8550 - val_loss: 1.8519
# Epoch 128/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8543 - val_loss: 1.8546
# Epoch 129/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8545 - val_loss: 1.8539
# Epoch 130/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8541 - val_loss: 1.8548
# Epoch 131/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8540 - val_loss: 1.8542
# Epoch 132/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8540 - val_loss: 1.8536
# Epoch 133/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8537 - val_loss: 1.8520
# Epoch 134/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8539 - val_loss: 1.8544
# Epoch 135/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8538 - val_loss: 1.8523
# Epoch 136/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8538 - val_loss: 1.8537
# Epoch 137/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8535 - val_loss: 1.8513
# Epoch 138/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8528 - val_loss: 1.8539
# Epoch 139/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8532 - val_loss: 1.8526
# Epoch 140/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8536 - val_loss: 1.8502
# Epoch 141/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8533 - val_loss: 1.8535
# Epoch 142/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8526 - val_loss: 1.8516
# Epoch 143/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8528 - val_loss: 1.8513
# Epoch 144/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8524 - val_loss: 1.8520
# Epoch 145/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8525 - val_loss: 1.8506
# Epoch 146/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8520 - val_loss: 1.8494
# Epoch 147/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8517 - val_loss: 1.8521
# Epoch 148/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8522 - val_loss: 1.8515
# Epoch 149/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8518 - val_loss: 1.8510
# Epoch 150/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8519 - val_loss: 1.8515
# Epoch 151/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8518 - val_loss: 1.8533
# Epoch 152/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8515 - val_loss: 1.8511
# Epoch 153/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8517 - val_loss: 1.8512
# Epoch 154/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8518 - val_loss: 1.8494
# Epoch 155/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8513 - val_loss: 1.8522
# Epoch 156/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8514 - val_loss: 1.8503
# Epoch 157/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8513 - val_loss: 1.8517
# Epoch 158/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8509 - val_loss: 1.8503
# Epoch 159/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8507 - val_loss: 1.8511
# Epoch 160/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8504 - val_loss: 1.8505
# Epoch 161/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8507 - val_loss: 1.8505
# Epoch 162/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8512 - val_loss: 1.8512
# Epoch 163/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8506 - val_loss: 1.8499
# Epoch 164/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8506 - val_loss: 1.8499
# Epoch 165/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8507 - val_loss: 1.8508
# Epoch 166/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8505 - val_loss: 1.8490
# Epoch 167/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8502 - val_loss: 1.8493
# Epoch 168/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8501 - val_loss: 1.8474
# Epoch 169/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8497 - val_loss: 1.8500
# Epoch 170/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8506 - val_loss: 1.8475
# Epoch 171/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8506 - val_loss: 1.8482
# Epoch 172/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8497 - val_loss: 1.8472
# Epoch 173/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8495 - val_loss: 1.8497
# Epoch 174/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8496 - val_loss: 1.8493
# Epoch 175/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8494 - val_loss: 1.8481
# Epoch 176/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8494 - val_loss: 1.8482
# Epoch 177/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8496 - val_loss: 1.8487
# Epoch 178/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8492 - val_loss: 1.8486
# Epoch 179/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8494 - val_loss: 1.8496
# Epoch 180/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8495 - val_loss: 1.8492
# Epoch 181/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8492 - val_loss: 1.8468
# Epoch 182/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8489 - val_loss: 1.8479
# Epoch 183/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8493 - val_loss: 1.8475
# Epoch 184/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8489 - val_loss: 1.8474
# Epoch 185/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8492 - val_loss: 1.8467
# Epoch 186/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8486 - val_loss: 1.8482
# Epoch 187/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8490 - val_loss: 1.8479
# Epoch 188/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8492 - val_loss: 1.8480
# Epoch 189/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8479 - val_loss: 1.8483
# Epoch 190/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8489 - val_loss: 1.8468
# Epoch 191/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8483 - val_loss: 1.8494
# Epoch 192/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8484 - val_loss: 1.8494
# Epoch 193/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8489 - val_loss: 1.8468
# Epoch 194/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8482 - val_loss: 1.8474
# Epoch 195/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8480 - val_loss: 1.8461
# Epoch 196/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8478 - val_loss: 1.8463
# Epoch 197/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8476 - val_loss: 1.8470
# Epoch 198/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8477 - val_loss: 1.8458
# Epoch 199/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8477 - val_loss: 1.8450
# Epoch 200/200
# 1674/1674 [==============================] - 13s 8ms/step - loss: 1.8482 - val_loss: 1.8468

# %%
# serialize weights to HDF5
bnn.save_weights("./bnn.h5")

# %%
bnn.load_weights("./bnn.h5")

# %%
plt.plot( history.history['loss'], label="loss")
plt.plot( history.history['val_loss'], label="val_loss")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.ylim(1.5,4)
# Out:
# (1.5, 4.0)

# %% [markdown]
# #### Compute Uncertainties

# %%
# Obtain 100 distributions for each test value
means = np.zeros( shape=(100,scaledXtest_pca.shape[0]) )
variances = np.zeros( shape=(100,scaledXtest_pca.shape[0]) )

for i in range(100):

    predictions = bnn(scaledXtest_pca)
    means[i,:] = np.array( predictions.mean()[:,0] )
    variances[i,:] = np.array( predictions.variance()[:,0] )

means.shape, variances.shape
# Out:
# ((100, 133862), (100, 133862))

# %%
# Aleatoric Uncertainty
aleatoric = getAleatoric(variances)

#Epsitemic Uncertainty
epistemic = getEpistemic(means)

len(aleatoric), len(epistemic)
# Out:
# (133862, 133862)

# %%
aggregatedVar = np.array(aleatoric) + np.array(epistemic)
aggregatedVar.shape
# Out:
# (133862,)

# %% [markdown]
# #### Aggregated Predictions

# %%
aggregatedMean = np.mean( means, axis=0 )
aggregatedMean.shape
# Out:
# (133862,)

# %%
# Determine widths of 95% credible interval
import arviz as az

counter  = 0

count = 0
widths = []

n = len(yTest)

for i in range(n):
    
    samples = np.random.normal( loc=aggregatedMean[i], 
                               scale=np.sqrt(aggregatedVar[i]), size=1000)

    hdi = az.hdi(samples,hdi_prob=0.95)
    if( (yTest[i] >= hdi[0]) and (yTest[i] <= hdi[1])): count += 1
    widths.append(hdi[1]-hdi[0])
    
    if ( counter < 3 ): 
        print( hdi, testLat[i], testLon[i], 
               np.round(aggregatedMean[i],2), np.round(aggregatedVar[i],2), np.round(yTest[i],2), 
               np.round(epistemic[i],2), np.round(aleatoric[i],2) )
        counter += 1

count/n
# Out:
# [16.36206886 24.84230731] 39.24696470167119 -76.62413176325326 20.45 4.74 21.12 0.08 4.66
# [24.52689705 30.49404944] 39.32871474694949 -76.57625155122828 27.46 2.34 25.9 0.08 2.26
# [23.67284764 29.06848061] 39.36506692951514 -76.58647064102884 26.47 2.05 27.32 0.02 2.04
# 0.9509121333911043

# %% [markdown]
# ### MAE

# %%
mean_absolute_error(yTest, aggregatedMean)
# Out:
# 1.210446738729275

# %%
def cTof (c):
    return (c * 9/5) + 32

# %%
plt.scatter( cTof(yTest), cTof(aggregatedMean) )
plt.ylabel('Predicted LST')
plt.xlabel('Actual LST')
plt.xlim(40,100)
plt.ylim(40,100)
# Out:
# (40.0, 100.0)

# %%
np.max(xTest[:,1]) # which column has a max of 12.9, which is the max BSEC distance?
# Out:
# 12.96575991408698

# %%
r = aggregatedMean - yTest
plt.scatter( xTest[:,1], r )
plt.xlabel('Distance to BSEC station (km)')
plt.ylabel('Residual (prediction - actual)')
plt.ylim(-15,15)
# Out:
# (-15.0, 15.0)

# %%
plt.hist(r)
plt.xlabel('Residual LST')
plt.ylabel('Number of Occurances')
plt.title('Histogram of Prediction Residuals')
plt.yscale('log')
plt.xlim(-15,15)
# Out:
# (-15.0, 15.0)

# %%
plt.scatter( testLon, testLat, c=r )
plt.set_cmap("bwr") # set colors to be blue to red
plt.colorbar()
plt.clim(-15,15)
plt.title('Prediction Residuals')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# #### Example predictions

# %%
plt.scatter( testLon, testLat, c=aleatoric )
plt.colorbar()
plt.title('Aleatoric Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
plt.scatter( testLon, testLat, c=epistemic )
plt.colorbar()
plt.title('Epistemic Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
plt.scatter( testLon, testLat, c=xTest[:,1] )
plt.colorbar()
plt.title('Distance to Nearest BSEC Station')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
np.min(epistemic), np.max(epistemic)
# Out:
# (0.00013183298970488976, 0.9973677702660598)

# %%
# epistemic uncertainty thresholding

maes = []
percent = []

yTest = np.array(yTest)
mn, mx = np.min(epistemic), np.max(epistemic)
epiRange = np.linspace(mn, mx, 10)

for epi in epiRange:

    ix = np.where(epistemic <= epi)
    count = len(ix[0])
    subsetY = yTest[ix]
    subsetP = aggregatedMean[ix]
    mae = mean_absolute_error(subsetY, subsetP)
    mae = np.round(mae, 4)
    print("Epistemic Threshold:", np.round(epi,4), "MAE:", mae, ", % of Predictions Made:", count/len(y))
    maes.append(mae)
    percent.append(count/len(y))
# Out:
# Epistemic Threshold: 0.0001 MAE: 0.4537 , % of Predictions Made: 1.4940782209711807e-06
# Epistemic Threshold: 0.1109 MAE: 1.1679 , % of Predictions Made: 0.16094808227589946
# Epistemic Threshold: 0.2217 MAE: 1.2081 , % of Predictions Made: 0.19507282884288124
# Epistemic Threshold: 0.3325 MAE: 1.2107 , % of Predictions Made: 0.19887226975881095
# Epistemic Threshold: 0.4433 MAE: 1.2111 , % of Predictions Made: 0.19946392473431554
# Epistemic Threshold: 0.5542 MAE: 1.2112 , % of Predictions Made: 0.19967458976347247
# Epistemic Threshold: 0.665 MAE: 1.2112 , % of Predictions Made: 0.19981055088158087
# Epistemic Threshold: 0.7758 MAE: 1.2111 , % of Predictions Made: 0.19985089099354708
# Epistemic Threshold: 0.8866 MAE: 1.2111 , % of Predictions Made: 0.19992260674815368
# Epistemic Threshold: 0.9974 MAE: 1.211 , % of Predictions Made: 0.20000029881564418

# %%
# Visual display of epistemic uncertainty thresholding
plt.plot(percent, maes,'-o')
plt.title("Proportion of Predictions vs MAE")
plt.xlabel("Proportion of Predictions Made")
plt.ylabel("MAE")
#plt.ylim(0.01,0.03)
#plt.colorbar()
# Out:
# Text(0, 0.5, 'MAE')

# %%
hdi
# Out:
# array([21.263304, 25.98143 ], dtype=float32)

# %%
# Visualize widths of credible intervals
plt.hist(widths)
plt.title("Credible Intervals Widths for Test Set")
plt.ylabel('Number of Occurances')
plt.xlabel('Width (Degrees)')
# Out:
# Text(0.5, 0, 'Width (Degrees)')

# %%
plt.scatter( testLon, testLat, c=widths )
plt.colorbar()
plt.title('Credible Interval Widths')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# ### Out of Distribution Examples

# %%
# harbor area
harbor = data[ (data['lstLat'] > 39.225) & (data['lstLat'] < 39.250) &
               (data['lstLon'] > -76.6) & (data['lstLon'] < -76.57) ]

harbor.shape
# Out:
# (25826, 43)

# %%
harbor.columns
# Out:
# Index(['fahrenheit', 'zscore', 'ndvi', 'lstLat', 'lstLon', 'stationID', 'tz',
#        'obsTimeUtc', 'obsTimeLocal', 'epoch', 'bsecLat', 'bsecLon',
#        'bsecDistance', 'solarRadiationHigh', 'uvHigh', 'winddirAvg',
#        'humidityHigh', 'humidityLow', 'humidityAvg', 'qcStatus', 'tempHigh',
#        'tempLow', 'tempAvg', 'windspeedHigh', 'windspeedLow', 'windspeedAvg',
#        'windgustHigh', 'windgustLow', 'windgustAvg', 'dewptHigh', 'dewptLow',
#        'dewptAvg', 'windchillHigh', 'windchillLow', 'windchillAvg',
#        'heatindexHigh', 'heatindexLow', 'heatindexAvg', 'pressureMax',
#        'pressureMin', 'pressureTrend', 'precipRate', 'precipTotal'],
#       dtype='object')

# %%
np.max( harbor.tempAvg )
# Out:
# 28.6

# %%
# average wind speed - 10
# average wind gust - 16
# ndvi - 0.8
#harbor.loc[:, 'windspeedAvg'] = 10
#harbor.loc[:, 'windgustAvg'] = 16
harbor.loc[:, 'tempAvg'] = 38

# %%
import pickle

with open('./scaler.pkl', 'rb') as file:
    scaler = pickle.load(file)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=7, svd_solver='full')

harborLat = harbor['lstLat']
harborLon = harbor['lstLon']

harbor = harbor.drop( columns=['fahrenheit','zscore','epoch','tz',
                        'stationID', 'obsTimeUtc', 'obsTimeLocal', 'qcStatus',
                        'bsecLat', 'bsecLon','precipRate','precipTotal', 'lstLat', 'lstLon'] )

harborScaled = scaler.transform(harbor)
print( harborScaled.shape )

harborPCA = pca.fit_transform(harborScaled)
print( harborPCA.shape )
# Out:
# (25826, 29)
# (25826, 7)

# %%
# Obtain 100 distributions for each test value
meansOOD = np.zeros( shape=(100,harborPCA.shape[0]) )
variancesOOD = np.zeros( shape=(100,harborPCA.shape[0]) )

for i in range(100):

    predictionsOOD = bnn(harborPCA)
    meansOOD[i,:] = np.array( predictionsOOD.mean()[:,0] )
    variancesOOD[i,:] = np.array( predictionsOOD.variance()[:,0] )

meansOOD.shape, variancesOOD.shape
# Out:
# ((100, 25826), (100, 25826))

# %%
# Aleatoric Uncertainty
aleatoricOOD = getAleatoric(variancesOOD)

#Epsitemic Uncertainty
epistemicOOD = getEpistemic(meansOOD)

len(aleatoricOOD), len(epistemicOOD)
# Out:
# (25826, 25826)

# %%
plt.hist(epistemic)
plt.hist(epistemicOOD, color='red')
plt.yscale('log')

# %%
plt.hist(aleatoric)
plt.hist(aleatoricOOD, color='red')
plt.yscale('log')

# %%
totalError = np.array(aleatoricOOD) + np.array(epistemicOOD)
plt.scatter( harborLon, harborLat, c=totalError )
plt.colorbar()

# %%
total = np.array(epistemic) + np.array(aleatoric)
plt.scatter( testLon, testLat, c=epistemic )
plt.colorbar()
plt.title('Total Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
total = np.array(epistemic) + np.array(aleatoric)
plt.scatter( testLon, testLat, c=epistemic )
plt.colorbar()
plt.title('Total Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.scatter( harborLon, harborLat, c=epistemicOOD )

# %%
ix = np.where( np.array(aleatoric) < 1 )[0]
print(len(ix))
testLat[ix[0:100]], testLon[ix[0:100]]
# Out:
# 265
# (array([39.35680085, 39.3496395 , 39.36878102, 39.35972664, 39.35656178,
#         39.34996521, 39.34509718, 39.35567225, 39.35883179, 39.34826058,
#         39.34647073, 39.34997444, 39.35959147, 39.35272417, 39.35441414,
#         39.34879175, 39.34057341, 39.35133019, 39.35988489, 39.35125622,
#         39.35985241, 39.34864748, 39.34955135, 39.34819092, 39.35457751,
#         39.34440777, 39.34437054, 39.34437519, 39.34023315, 39.35770918,
#         39.35788175, 39.35308286, 39.35702441, 39.35134863, 39.34983087,
#         39.34559079, 39.34111852, 39.35183831, 39.35257027, 39.35988025,
#         39.34992824, 39.34832075, 39.34788811, 39.35803042, 39.35062294,
#         39.34397864, 39.34393233, 39.3533991 , 39.35558446, 39.34994673,
#         39.34584708, 39.3414353 , 39.35444792, 39.34482167, 39.35971181,
#         39.35203909, 39.35995432, 39.35724787, 39.34712862, 39.35662298,
#         39.35040383, 39.35407996, 39.34868947, 39.3528915 , 39.35277543,
#         39.35072034, 39.3567121 , 39.35210854, 39.35546675, 39.34899229,
#         39.35225824, 39.34567968, 39.35433618, 39.34783108, 39.3568932 ,
#         39.34422109, 39.35549503, 39.34647634, 39.35360937, 39.35309679,
#         39.34702501, 39.35943305, 39.35262124, 39.34186852, 39.34024717,
#         39.33784785, 39.357919  , 39.34080164, 39.34926045, 39.34915988,
#         39.34748695, 39.3639707 , 39.34647167, 39.34682119, 39.36057932,
#         39.34722619, 39.34995135, 39.35403706, 39.35782574, 39.34717504]),
#  array([-76.55808079, -76.54782541, -76.53118407, -76.56162779,
#         -76.57583276, -76.5436548 , -76.56408708, -76.54134317,
#         -76.54768011, -76.54988383, -76.54218537, -76.54295871,
#         -76.55152705, -76.55973104, -76.57473999, -76.55059186,
#         -76.55876469, -76.54264037, -76.54979255, -76.54820925,
#         -76.55222922, -76.5613811 , -76.55443827, -76.55510441,
#         -76.54236363, -76.55502054, -76.55780469, -76.55745667,
#         -76.56397865, -76.55078903, -76.55810481, -76.55312388,
#         -76.56156761, -76.54124815, -76.55374817, -76.56757936,
#         -76.5584287 , -76.54508866, -76.55102355, -76.55014065,
#         -76.54643919, -76.54535932, -76.55753467, -76.56716104,
#         -76.55515833, -76.54665615, -76.55013633, -76.56984287,
#         -76.54795662, -76.54504699, -76.54843799, -76.55495466,
#         -76.5521096 , -76.54423787, -76.54247656, -76.55031549,
#         -76.54457109, -76.56505444, -76.55368831, -76.57130777,
#         -76.5513238 , -76.55941302, -76.55824875, -76.56739437,
#         -76.55590238, -76.56804215, -76.5646943 , -76.54509462,
#         -76.57685268, -76.55581846, -76.5541501 , -76.56096692,
#         -76.56046323, -76.541519  , -76.57131383, -76.54875023,
#         -76.57476426, -76.56202904, -76.55418004, -76.55207969,
#         -76.54115315, -76.56336223, -76.54719489, -76.56297078,
#         -76.56293466, -76.56044459, -76.55532013, -76.5619027 ,
#         -76.53563192, -76.56348138, -76.54708164, -76.54744533,
#         -76.56237707, -76.55646658, -76.55851296, -76.5665715 ,
#         -76.54469895, -76.54235174, -76.56228183, -76.55020798]))

# %%
ne = data[ (data['lstLat'] > 39.352) & (data['lstLat'] < 39.356) &
               (data['lstLon'] > -76.58) & (data['lstLon'] < -76.542) ]

ne.shape
# Out:
# (4863, 43)

# %%
neLat = ne['lstLat']
neLon = ne['lstLon']

ne = ne.drop( columns=['fahrenheit','zscore','epoch','tz',
                        'stationID', 'obsTimeUtc', 'obsTimeLocal', 'qcStatus',
                        'bsecLat', 'bsecLon','precipRate','precipTotal', 'lstLat', 'lstLon'] )

ne.loc[:, 'tempAvg'] = 38

neScaled = scaler.transform(ne)
print( neScaled.shape )

nePCA = pca.fit_transform(neScaled)
print( nePCA.shape )

# Obtain 100 distributions for each test value
meansOOD = np.zeros( shape=(100,nePCA.shape[0]) )
variancesOOD = np.zeros( shape=(100,nePCA.shape[0]) )

for i in range(100):

    predictionsOOD = bnn(nePCA)
    meansOOD[i,:] = np.array( predictionsOOD.mean()[:,0] )
    variancesOOD[i,:] = np.array( predictionsOOD.variance()[:,0] )

meansOOD.shape, variancesOOD.shape

# Aleatoric Uncertainty
aleatoricOOD = getAleatoric(variancesOOD)

#Epsitemic Uncertainty
epistemicOOD = getEpistemic(meansOOD)

len(aleatoricOOD), len(epistemicOOD)
# Out:
# (4863, 29)
# (4863, 7)
# (4863, 4863)

# %%
plt.hist(epistemic)
plt.hist(epistemicOOD, color='red')
plt.yscale('log')

# %%
plt.hist(aleatoric)
plt.hist(aleatoricOOD, color='red')
plt.yscale('log')

# %%
totalError = np.array(aleatoricOOD) + np.array(epistemicOOD)
plt.scatter( neLon, neLat, c=totalError )
plt.colorbar()

# %%
total = np.array(epistemic) + np.array(aleatoric)
plt.scatter( testLon, testLat, c=epistemic )
plt.colorbar()
plt.title('Total Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %%
total = np.array(epistemic) + np.array(aleatoric)
plt.scatter( testLon, testLat, c=epistemic )
plt.colorbar()
plt.title('Total Uncertainty')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.scatter( neLon, neLat, c=epistemicOOD )
